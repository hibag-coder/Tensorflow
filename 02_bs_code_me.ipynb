# %%
from bs4 import BeautifulSoup

# %%
page_02 = open("01_TextMining/data/02_test_first.html")
soup_02 = BeautifulSoup(page_02, 'html.parser')

# %%
print(soup_02)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
print(soup_02.children)

# %%
list(soup_02.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
list(soup_02.children)[0], list(soup_02.children)[1]
# Out:
# ('html', '\n')

# %%
html = list(soup_02.children)[2]
print(html)
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>, '\n', <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>, '\n']

# %%
list(html.children)[3]
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body = list(html.children)[3]
print(body)
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(body.children)
# Out:
# ['\n', <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>, '\n', <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, '\n', <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>, '\n']

# %%
divs = list(body.children)[1]
print(divs)
# Out:
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>

# %%
outer_text_class_first = soup.find('p',class_='outer-text')
print(outer_text_class_first)
# Out:
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>

# %%
outer_text_class = soup.find_all('p',class_='outer-text')
print(outer_text_class)
# Out:
# [<p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>, <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>]

# %%
first_id = soup.find_all('p',id='first')
print(first_id)
# Out:
# [<p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>]

# %%
soup_02.find_all(id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup_02.find_all(class_='inner-text')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>]

# %%
soup_02.find_all(class_='inner-text second-item')
# Out:
# [<p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>]

# %%
soup_02.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup_02.head.next_sibling
# Out:
# '\n'

# %%
soup_02.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
#body.find('p')
body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
body.p.next_sibling
# Out:
# '\n'

# %%
body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
for each_tab in soup_02.find_all('p'):
    print(each_tab.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
body.getText()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup_02.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each.get('href')
    #href = each['href']
    text = each.string
    print(text + ' -> '+ href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %%
links[0].get('href')
# Out:
# 'http://www.pinkwink.kr'

# %%
links[0]['href']
# Out:
# 'http://www.pinkwink.kr'

# %%
links[0].string
# Out:
# 'PinkWink'

# %%
from urllib.request import urlopen

# %%
url = "https://finance.naver.com/marketindex/"
page03 = urlopen(url)

# %%
soup03 = BeautifulSoup(page03, 'html.parser')

# %%
soup03
# Out:
# <script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <script language="JavaScript" src="/js/flashObject.js?20190903164201"></script>
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,181.00</span>
# ...

# %%
market_data = soup03.find('div', class_='market_data');
print(market_data)
# Out:
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,181.00</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">1.00</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2019.10.18 20:01</span>
# ...

# %%
lis = market_data.find_all('li')
print(lis)
# Out:
# [<li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,181.00</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">1.00</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2019.10.18 20:01</span>
# <span class="source">KEB하나은행 기준</span>
# <span class="count">고시회차<span class="num">306</span>회</span>
# </div>
# </li>, <li class="">
# ...

# %%
len(lis)
# Out:
# 12

# %%
lis[0]
# Out:
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,181.00</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">1.00</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2019.10.18 20:01</span>
# <span class="source">KEB하나은행 기준</span>
# <span class="count">고시회차<span class="num">306</span>회</span>
# </div>
# </li>

# %%
lis[0].find('h3').getText()
# Out:
# '미국 USD'

# %%
lis[0].find('span', class_='value').getText()
# Out:
# '1,181.00'

# %%
lis[0].find('span', class_='change').getText()
# Out:
# '1.00'

# %%
for li in lis :
    #li.find('h3').getText()
    print(li.find('h3').getText()+'는 ' + li.find('span', class_='value').getText()+' 원 입니다.')
# Out:
# 미국 USD는 1,181.00 원 입니다.
# 일본 JPY(100엔)는 1,086.83 원 입니다.
# 유럽연합 EUR는 1,314.81 원 입니다.
# 중국 CNY는 166.71 원 입니다.
# 일본 엔/달러는 108.4000 원 입니다.
# 달러/유로는 1.1169 원 입니다.
# 달러/영국파운드는 1.2985 원 입니다.
# 달러인덱스는 97.0000 원 입니다.
# WTI는 53.78 원 입니다.
# 휘발유는 1539.6 원 입니다.
# 국제 금는 1488.2 원 입니다.
# 국내 금는 56490.77 원 입니다.

# %%
for li in lis:
    print(li.find('h3').string + ' : ' + li.find('span', class_='value').string)
# Out:
# 미국 USD : 1,181.00
# 일본 JPY(100엔) : 1,086.83
# 유럽연합 EUR : 1,314.81
# 중국 CNY : 166.71
# 일본 엔/달러 : 108.4000
# 달러/유로 : 1.1169
# 달러/영국파운드 : 1.2985
# 달러인덱스 : 97.0000
# WTI : 53.78
# 휘발유 : 1539.6
# 국제 금 : 1488.2
# 국내 금 : 56490.77
